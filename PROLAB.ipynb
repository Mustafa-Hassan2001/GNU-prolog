# %% [markdown]
# SWI and GNU is same
#
# Prolog: is a logical programmming
#
# it depends on relation/rule and base on that it answer the quires
#
# Facts -> user define
#  |
# Rule
#
#
# Knowladge base system =  Facts + Rule => Quries => LP
#
# file name [file name].
#
#
# Rule  :-
#
# capital -> varible
# small -> string
#
# text may
# male(name).
# female(name).
#
# parent(name, fname).
#
# =< GRATER EQUAL
# =:= EQUAL EQUAL TO
# \= ONT EQUAL
#
# good_grades(sudent, subject) :- teaches(teacher, subject), likes(teacher, student).
#
# good_grades(Student, Teacher) :- student(Student), teacher(Teacher), studies(Student, _, Teacher).
#
#
#
#
# % Facts
# male(arham).
# male(rizwan).
# male(aliyan).
# female(sadaf).
# female(saira).
#
# teacher(arham).
# teacher(rizwan).
#
# bestfriend(saira, sadaf).
# friend(saira, sadaf).
# friend(aliyan, sadaf).
# bestfriend(arham, sadaf).
#
# student(arham).
# student(aliyan).
# student(sadaf).
# student(saira).
#
# studies(sadaf, math, rizwan).
# studies(arham, math, rizwan).
#
# mutual_friend(X, Y) :- friend(X, Y), friend(Y, X).
#
# classfellow(X, Y) :- student(X), student(Y), X \= Y.
#
# good_grades(X, Y) :- student(X), teacher(Y), studies(X, _, Y).
#
# mutual_bestfriends(X, Y) :- bestfriend(X, Y), bestfriend(Y, X).
#
#
# ?- mutual_friend(saira, sadaf).
# true.
#
# ?- mutual_friend(arham, rizwan).
# false.
#
# ?- mutual_friend(saira, aliyan).
# false.
#
# ?- classfellow(saira, aliyan).
# true.
#
# ?- classfellow(arham, sadaf).
# true.
#
# ?- classfellow(arham, rizwan).
# false.
#
#
# ?- good_grades(arham, rizwan).
# true.
#
# ?- good_grades(sadaf, rizwan).
# true.
#
# ?- good_grades(aliyan, rizwan).
# false.
#
#
# ?- mutual_bestfriends(saira, sadaf).
# true.
#
# ?- mutual_bestfriends(arham, sadaf).
# true.
#
# ?- mutual_bestfriends(saira, arham).
# false.

# %%
mutual_friends(X, Y) :-
    friend(X, Z),
    friend(Y, Z),
    X \= Y.

classfellow(X, Y) :-
    student(X),
    student(Y),
    X \= Y.

good_grades(X, Y) :-
    student(X),
    teacher(Y),
    studies(X, _, Y).

mutual_bestfriends(X, Y) :-
    bestfriends(X, Y),
    bestfriends(Y, X).
